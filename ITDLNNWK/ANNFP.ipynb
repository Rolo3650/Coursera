# %%
import numpy as np # import Numpy library to generate 

weights = np.around(np.random.uniform(size=6), decimals=2) # initialize the weights
biases = np.around(np.random.uniform(size=3), decimals=2) # initialize the biases

print("Weights:", weights)
print("Biases:", biases)
# Out:
# Weights: [0.47 0.04 0.08 0.73 0.64 0.03]
# Biases: [0.3  0.22 0.06]

# %%
x_1 = 0.5 # input 1
x_2 = 0.85 # input 2

print('x1 is {} and x2 is {}'.format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %%
z_11 = x_1 * weights[0] + x_2 * weights[1] + biases[0]

print('The weighted sum of the inputs at the first node in the hidden layer is {}'.format(z_11))
# Out:
# The weighted sum of the inputs at the first node in the hidden layer is 0.569

# %%
z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]

print('The weighted sum of the inputs at the second node in the hidden layer is {}'.format(z_12))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 0.8805

# %%
a_11 = 1.0 / (1.0 + np.exp(-z_11))

print('The activation of the first node in the hidden layer is {}'.format(np.around(a_11, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.6385

# %%
### type your answer here
a_12 = 1.0 / (1.0 + np.exp(-z_12))

print('The activation of the second node in the hidden layer is {}'.format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.7069

# %%
z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]

print('The weighted sum of the inputs at the second node in the hidden layer is {}'.format(z_2))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 0.48986850963252865

# %%
a_2 = 1.0 / (1.0 + np.exp(-z_2))

print('The activation of the first node in the hidden layer is {}'.format(np.around(a_2, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.6201

# %% [markdown]
# # Construir una red neuronal

# %%
n = 2 # number of inputs
num_hidden_layers = 2 # number of hidden layers
m = [2, 2] # number of nodes in each hidden layer
num_nodes_output = 1 # number of nodes in the output layer

# %%
import numpy as np

num_nodes_previous = n

network = {}

for layer in range(num_hidden_layers + 1):
    
    if layer == num_hidden_layers:
        layer_name = 'output'
        num_nodes = num_nodes_output
    else:
        layer_name = 'layer{}'.format(layer + 1)
        num_nodes = m[layer]
    
    network[layer_name] = {}
    for node in range(num_nodes):
        node_name = 'node{}'.format(node + 1)
        network[layer_name][node_name] = {
            'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
            'bias': np.around(np.random.uniform(), decimals=2)
        }
    
    num_nodes_previous = num_nodes
    
print(network)
# Out:
# {'layer1': {'node1': {'weights': array([0.52, 0.42]), 'bias': np.float64(0.05)}, 'node2': {'weights': array([0.57, 0.8 ]), 'bias': np.float64(0.11)}}, 'layer2': {'node1': {'weights': array([0.28, 0.64]), 'bias': np.float64(0.49)}, 'node2': {'weights': array([0.51, 0.46]), 'bias': np.float64(0.89)}}, 'output': {'node1': {'weights': array([0.61, 0.6 ]), 'bias': np.float64(0.44)}}}

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):
    num_nodes_previous = num_inputs
    
    network = {}
    
    for layer in range(num_hidden_layers + 1):
        
        if layer == num_hidden_layers:
            layer_name = 'output'
            num_nodes = num_nodes_output
        else:
            layer_name = 'layer{}'.format(layer + 1)
            num_nodes = num_nodes_hidden[layer]
        
        network[layer_name] = {}
        for node in range(num_nodes):
            node_name = 'node{}'.format(node + 1)
            network[layer_name][node_name] = {
                'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
                'bias': np.around(np.random.uniform(), decimals=2)
            }
        
        num_nodes_previous = num_nodes
    
    return network

# %%
small_network = initialize_network(5, 3, [3, 2, 3], 1)

# %%
def compute_weighted_sum(inputs, weights, bias):
    return np.sum(inputs * weights) + bias

# %%
from random import seed
import numpy as np

np.random.seed(12)
inputs = np.around(np.random.uniform(size=5), decimals=2)

print('The inputs to the network are {}'.format(inputs))
# Out:
# The inputs to the network are [0.15 0.74 0.26 0.53 0.01]

# %%
node_weights = small_network['layer1']['node1']['weights']
node_bias = small_network['layer1']['node1']['bias']

weighted_sum = compute_weighted_sum(inputs, node_weights, node_bias)

# %%
def node_activation(weighted_sum):
    return 1.0 / (1.0 + np.exp(-1 * weighted_sum))

# %%
node_output  = node_activation(compute_weighted_sum(inputs, node_weights, node_bias))

# %%
def forward_propagate(network, inputs):
    layer_inputs = list(inputs)
    
    for layer in network:
        layer_data = network[layer]
        
        layer_outputs = []
        for layer_node in layer_data:
            node_data = layer_data[layer_node]
            
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(node_output)
        
        if layer != 'output':
            print('The outputs of the nodes in {} are {}'.format(layer, np.around(layer_outputs, decimals=4)))
        
        layer_inputs = layer_outputs
        
    network_prediction = layer_outputs
    return network_prediction

# %%
my_network = initialize_network(5, 3, [2, 3, 2], 3)

# %%
inputs = np.around(np.random.uniform(size=5), decimals=2)

# %%
predictions = forward_propagate(my_network, inputs)
print('The predicted values by the network for the given input are {}'.format(predictions))
# Out:
# The outputs of the nodes in layer1 are [0.8857 0.8889]
# The outputs of the nodes in layer2 are [0.7822 0.6965 0.7411]
# The outputs of the nodes in layer3 are [0.868 0.881]
# The predicted values by the network for the given input are [np.float64(0.8952133845993373), np.float64(0.8222523426728204), np.float64(0.8034847090956094)]
